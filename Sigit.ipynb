# %%
ls
# Out:
# CITATION.cff           Untitled.ipynb         requirements.txt
# Framework/             Untitled1.ipynb        results/
# LICENSE                locations/             scripts/
# README.md              lora_simulator_v2.png
# Simulations/           pyitm/

# %%
# !python -m Simulations.Example.simulation
# Out:
# Simulation #0
# 126224308.6663221 ms delayed prior to joining (Node -> run)
# 4 joining the network (Node -> run)
# 4: joined the network (Node -> run)
# 4: START sleeping (Node -> run)
# 145008495.5556472 ms delayed prior to joining (Node -> run)
# 0 joining the network (Node -> run)
# 0: joined the network (Node -> run)
# 0: START sleeping (Node -> run)
# 149258842.9902768 ms delayed prior to joining (Node -> run)
# 2 joining the network (Node -> run)
# 2: joined the network (Node -> run)
# 2: START sleeping (Node -> run)
# 252939897.79383862 ms delayed prior to joining (Node -> run)
# 1 joining the network (Node -> run)
# 1: joined the network (Node -> run)
# 1: START sleeping (Node -> run)
# 4: PROCESSING (Node -> run)
# 4: SENDING packet (Node -> run)
# 4: 	 TX (Node -> send_tx)
#
# 		 AIR INTERFACE
# rss_itm:  -112.36558323802608
# CHECK node 4 (sf:8 bw:125 freq:8.681000e+08) (AirInterface -> collision)#others: 1
# Total number of packets in the air 1
# ...
